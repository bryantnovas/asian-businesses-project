# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %% [markdown]
# # Table of Contents:
#
# [1.Introduction & Hypothesis](#1)<br>
# [2.Analysis on our Data](#2)<br>
# [3.Conclusions](#3)<br>

# %% [markdown]
# ## Introduction & Hypothesis <a id='1'></a>:
#
# ### Introduction:
#     What is the SBA Loan?
#     an SBA loan is a small business loan that is partially guaranteed by the government (the Small Business Administration), which eliminates some of the risk for the financial institution who is issuing the loan.
#     SBA loans can range in size anywhere from $500 to $5.5 million and can offer APR’s as low as 6.5%. Additionally, repayment terms for SBA loans can range from 5 to 25 years, but 10 years is a standard SBA loan repayment term length.
#     This notebook will be analyzing the data from the website below regarding SBA loans in New York.
#   <a href=" https://web.sba.gov/dsbs/search/dsp_dsbs.cfm"> click here</a>
#
# ### Hypothesis:
#      My hypotheis is that financial resources such as the SBA loan are not being distributed to the small businesses in the communities that need the assistance the most.
#
#      The data in this notebook will show the how many businesses recieve financial assistance through SBA loans by borough.

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('SBA_dataset.csv')

# %%
df.head(3)
# Out:
#   This profile was last updated  Status   User ID  \
# 0                    04/26/2021  Active  P2602860
# 1                    05/13/2021  Active  P1704930
# 2                    08/25/2020  Active  P2499434
#
#                     Name of Firm Trade Name ("Doing Business As ...")  \
# 0        TRAINED FOR CARE, CORP.                                  NaN
# 1        MNS Pro Companies, Inc.                                  NaN
# 2  New Yorkers International LLC                                  NaN
#
#    DUNS Number  Parent DUNS Number          Address, line 1  Address, line 2  \
# 0    117990138                 NaN             28 BRYANT RD              NaN
# 1     78514224                 NaN  807 South Geddes Street              NaN
# 2     78791446                 NaN      8508 Astoria Blvd 1              NaN
#
#             City State         Zip  Phone Number Fax Number  \
# 0         CARMEL    NY  10512-5617  833-964-1011        NaN
# 1       Syracuse    NY  13204-3617  315-657-1846        NaN
# 2  East Elmhurst    NY  11369-1656  347-566-1011        NaN
#
#              E-mail Address WWW Page E-Commerce Website  Contact Person  \
# 0  oyane@trainedforcare.com      NaN                NaN  Oyane  Jacques
# 1   moe@mnsprocompanies.com      NaN                NaN  Moses Scoggins
# 2    impartialnyc@gmail.com      NaN                NaN     Nimer Dewan
#
#    County Code (3 digit)  Congressional District  \
# 0                     79                      18
# 1                     67                      24
# 2                     81                      14
#
#    Metropolitan Statistical Area CAGE Code  Year Established  \
# 0                         5600.0     8ZGC9              2020
# 1                         8160.0     6UK94              2012
# 2                         5600.0     8PJP7              2011
#
#   Accepts Government Credit Card? GSA Advantage Contract(s)
# 0                 [  ] Yes [X] No                       NaN
# 1                 [X] Yes [  ] No                       NaN
# 2                 [X] Yes [  ] No                       NaN

# %% [markdown]
# ## Analysis on our data <a id='2'></a> :

# %%
df['City'] = df['City'].str.lower()

# %%
# The average year established for these businesses is 2011
df['Year Established'].mean()
# Out:
# 2011.1719626168224

# %%
Queens = ['arverne', 'astoria', 'bayside', 'bellerose', 'breezy point', 'cambria heights',
          'college point', 'corona east', 'elmhurst', 'elmhurst', 'far rockaway', 'floral park', 'flushing',
          'forest hills', 'fresh meadows', 'glen oaks', 'hollis', 'howard beach', 'jackson heights', 'jamaica', 'kew gardens',
          'little neck', 'long island city', 'maspeth', 'middle village', 'oakland gardens', 'ozone park', 'queens village', 'rego park',
          'richmond hill', 'ridgewood', 'rockaway park', 'rosedale', 'saint albans', 'south ozone park', 'south richmond hill', 'springfield gardens', 'sunnyside', 'whitestone', 'woodhaven', 'woodside']
print(Queens)
df.loc[(df.City.isin(Queens)),'City']='queens'
# Out:
# ['arverne', 'astoria', 'bayside', 'bellerose', 'breezy point', 'cambria heights', 'college point', 'corona east', 'elmhurst', 'elmhurst', 'far rockaway', 'floral park', 'flushing', 'forest hills', 'fresh meadows', 'glen oaks', 'hollis', 'howard beach', 'jackson heights', 'jamaica', 'kew gardens', 'little neck', 'long island city', 'maspeth', 'middle village', 'oakland gardens', 'ozone park', 'queens village', 'rego park', 'richmond hill', 'ridgewood', 'rockaway park', 'rosedale', 'saint albans', 'south ozone park', 'south richmond hill', 'springfield gardens', 'sunnyside', 'whitestone', 'woodhaven', 'woodside']

# %%
Bronx = ['allerton', 'baychester', 'bedford park', 'belmont', 'castle hill', 'city island', 
 'clason point', 'co-op city', 'eastchester', 'edenwald', 'fordham', 'highbridge', 'hunts point', 'kingsbridge', 'longwood', 'marble hill',
 'melrose', 'morris heights', 'morris park', 'morrisania', 'mott haven', 'mount hope', 'norwood', 'parkchester', 'pelham bay', 'riverdale', 'soundview', 'the hub', 'throgs neck', 'tremont', 'university heights', 'wakefield', 'west farms', 'westchester', 'williamsbridge', 'woodlawn']
print(Bronx)
df.loc[(df.City.isin(Bronx)),'City']='bronx'
# Out:
# ['allerton', 'baychester', 'bedford park', 'belmont', 'castle hill', 'city island', 'clason point', 'co-op city', 'eastchester', 'edenwald', 'fordham', 'highbridge', 'hunts point', 'kingsbridge', 'longwood', 'marble hill', 'melrose', 'morris heights', 'morris park', 'morrisania', 'mott haven', 'mount hope', 'norwood', 'parkchester', 'pelham bay', 'riverdale', 'soundview', 'the hub', 'throgs neck', 'tremont', 'university heights', 'wakefield', 'west farms', 'westchester', 'williamsbridge', 'woodlawn']

# %%
Staten_Island = ['annadale', 'arden heights', 'arlington', 'arrochar', 'bay terrace', 
 'bloomfield', 'brighton heights', 'bulls head', 'castleton', 'castleton corners', 'charleston', 'chelsea', 'clifton', 'concord', 
 'dongan hills', 'egbertville', 'elm park', 'eltingville', 'emerson hill', 'fort wadsworth', 'graniteville', 'grant city', 'grasmere', 'great kills', 'greenridge', 'grymes hill', 'hamilton park', 'heartland village', 'huguenot', 'lighthouse hill', 'livingston', 'manor heights', 'mariners harbor', 'meiers corners', 'midland beach', 'new brighton', 'new dorp', 'new springville', 'oakwood', 'ocean breeze', 'old place', 'old town', 'pleasant plains', 'port richmond', 'prince’s bay', 'randall manor', 'richmond valley', 'richmondtown', 'rosebank', 'rossville', 'sandy ground', 'shore acres', 'silver lake', 'south beach', 'st.george', 'stapleton', 'stapleton heights', 'sunnyside', 'todt hill', 'tompkinsville']
print(Staten_Island)
df.loc[(df.City.isin(Staten_Island)),'City']='staten island'
# Out:
# ['annadale', 'arden heights', 'arlington', 'arrochar', 'bay terrace', 'bloomfield', 'brighton heights', 'bulls head', 'castleton', 'castleton corners', 'charleston', 'chelsea', 'clifton', 'concord', 'dongan hills', 'egbertville', 'elm park', 'eltingville', 'emerson hill', 'fort wadsworth', 'graniteville', 'grant city', 'grasmere', 'great kills', 'greenridge', 'grymes hill', 'hamilton park', 'heartland village', 'huguenot', 'lighthouse hill', 'livingston', 'manor heights', 'mariners harbor', 'meiers corners', 'midland beach', 'new brighton', 'new dorp', 'new springville', 'oakwood', 'ocean breeze', 'old place', 'old town', 'pleasant plains', 'port richmond', 'prince’s bay', 'randall manor', 'richmond valley', 'richmondtown', 'rosebank', 'rossville', 'sandy ground', 'shore acres', 'silver lake', 'south beach', 'st.george', 'stapleton', 'stapleton heights', 'sunnyside', 'todt hill', 'tompkinsville']

# %%
Manhattan = '''
Alphabet City
Astor Row
Battery Park City
Bowery
Carnegie Hill
Chelsea
Chinatown
Civic Center
Columbus Circle
Cooperative Village
Diamond District
Downtown Manhattan
East Harlem
East Village
Financial District
Five Points
Flatiron District
Fort George
Garment District
Gramercy Park
Greenwich Village
Hamilton Heights
Hell’s Kitchen
Herald Square
Hudson Yards
Inwood
Kips Bay
Koreatown
Lenox Hill
Lincoln Square
Little Germany
Little Italy
Lower East Side
Madison Square
Manhattan Valley
Marble Hill
Marcus Garvey Park
Meatpacking District
Midtown
Morningside Heights
Murray Hill
NoHo
Nolita
NoMad
Battery Park City
Radio Row
Rockefeller Center
Rose Hilll
SoHo
South Street Seaport
Strivers’ Row
Stuyvesant Square
Stuyvesant Town
Sugar Hill
Sutton Place
Tenderloin
Theater District
Times Square
Tribeca
Tudor City
Turtle Bay
Two Bridges
Union Square
Upper East Side
Upper West Side
Washington Heights
Waterside Plaza
West Village
Yorkville
'''
Manhattan_list = Manhattan.lower().split()
print(Manhattan_list)
df.loc[(df.City.isin(Manhattan_list)),'City']='manhattan'
# Out:
# ['alphabet', 'city', 'astor', 'row', 'battery', 'park', 'city', 'bowery', 'carnegie', 'hill', 'chelsea', 'chinatown', 'civic', 'center', 'columbus', 'circle', 'cooperative', 'village', 'diamond', 'district', 'downtown', 'manhattan', 'east', 'harlem', 'east', 'village', 'financial', 'district', 'five', 'points', 'flatiron', 'district', 'fort', 'george', 'garment', 'district', 'gramercy', 'park', 'greenwich', 'village', 'hamilton', 'heights', 'hell’s', 'kitchen', 'herald', 'square', 'hudson', 'yards', 'inwood', 'kips', 'bay', 'koreatown', 'lenox', 'hill', 'lincoln', 'square', 'little', 'germany', 'little', 'italy', 'lower', 'east', 'side', 'madison', 'square', 'manhattan', 'valley', 'marble', 'hill', 'marcus', 'garvey', 'park', 'meatpacking', 'district', 'midtown', 'morningside', 'heights', 'murray', 'hill', 'noho', 'nolita', 'nomad', 'battery', 'park', 'city', 'radio', 'row', 'rockefeller', 'center', 'rose', 'hilll', 'soho', 'south', 'street', 'seaport', 'strivers’', 'row', 'stuyvesant', 'square', 'stuyvesant', 'town', 'sugar', 'hill', 'sutton', 'place', 'tenderloin', 'theater', 'district', 'times', 'square', 'tribeca', 'tudor', 'city', 'turtle', 'bay', 'two', 'bridges', 'union', 'square', 'upper', 'east', 'side', 'upper', 'west', 'side', 'washington', 'heights', 'waterside', 'plaza', 'west', 'village', 'yorkville']

# %%
Brooklyn = ['admirals row', 'atura', 'barren island', 'bath beach', 'bay ridge', 'bedford', 'bedford-stuyvesant', 'bensonhurst',
 'bergen beach', 'bococa', 'boerum hill', 'borough park', 'brighton beach', 'brooklyn heights', 'brownsville', 'bushwick', 'cadman plaza',
 'canarsie', 'carroll gardens', 'city line', 'clinton hill', 'cobble hill', 'coney island', 'crown heights', 'cypress hills', 'ditmas park', 
 'downtown dumbo', 'dyker heights', 'east flatbush', 'east new york', 'east williamsburg', 'farragut', 'fiske terrace', 'flatbush', 'flatlands', 'fort greene', 'fort hamilton', 'fulton ferry', 'georgetown', 'gerritsen beach', 'gowanus', 'gravesend', 'greenpoint', 'greenwood heights', 'highland park', 'homecrest', 'kensington', 'little poland', 'madison,', 'manhattan beach', 'marine park', 'midwood', 'mill basin', 'navy yard', 'new lots', 'new utrecht', 'ocean hill', 'ocean parkway', 'park slope', 'pigtown', 'plum beach', 'prospect heights', 'prospect park', 'south prospect', 'lefferts gardens', 'rambo', 'red hook', 'sea gate', 'sheepshead bay', 'south brooklyn', 'south park slope', 'starrett city', 'stuyvesant heights', 'sunset park', 'vinegar hill', 'weeksville', 'white sands', 'williamsburg', 'windsor terrace', 'wingate']
print(Brooklyn)
df.loc[(df.City.isin(Brooklyn)),'City']='brooklyn'
# Out:
# ['admirals row', 'atura', 'barren island', 'bath beach', 'bay ridge', 'bedford', 'bedford-stuyvesant', 'bensonhurst', 'bergen beach', 'bococa', 'boerum hill', 'borough park', 'brighton beach', 'brooklyn heights', 'brownsville', 'bushwick', 'cadman plaza', 'canarsie', 'carroll gardens', 'city line', 'clinton hill', 'cobble hill', 'coney island', 'crown heights', 'cypress hills', 'ditmas park', 'downtown dumbo', 'dyker heights', 'east flatbush', 'east new york', 'east williamsburg', 'farragut', 'fiske terrace', 'flatbush', 'flatlands', 'fort greene', 'fort hamilton', 'fulton ferry', 'georgetown', 'gerritsen beach', 'gowanus', 'gravesend', 'greenpoint', 'greenwood heights', 'highland park', 'homecrest', 'kensington', 'little poland', 'madison,', 'manhattan beach', 'marine park', 'midwood', 'mill basin', 'navy yard', 'new lots', 'new utrecht', 'ocean hill', 'ocean parkway', 'park slope', 'pigtown', 'plum beach', 'prospect heights', 'prospect park', 'south prospect', 'lefferts gardens', 'rambo', 'red hook', 'sea gate', 'sheepshead bay', 'south brooklyn', 'south park slope', 'starrett city', 'stuyvesant heights', 'sunset park', 'vinegar hill', 'weeksville', 'white sands', 'williamsburg', 'windsor terrace', 'wingate']

# %%
# setting any city in the dataframe that is not apart of the 5 boroughs to "other"
df.loc[(~df.City.isin(['brooklyn','bronx','queens','staten island',"manhattan"])),'City']='other'

# %%
df
# Out:
#     This profile was last updated  Status   User ID  \
# 0                      04/26/2021  Active  P2602860
# 1                      05/13/2021  Active  P1704930
# 2                      08/25/2020  Active  P2499434
# 3                      05/31/2021  Active  P2557651
# 4                      02/10/2021  Active  P2584073
# ..                            ...     ...       ...
# 530                    03/05/2021  Active  P2479446
# 531                    03/18/2021  Active  P2498415
# 532                    11/13/2020  Active  P1009983
# 533                    03/27/2021  Active  PN100341
# 534                    02/01/2021  Active  P2388007
#
#                                           Name of Firm  \
# 0                              TRAINED FOR CARE, CORP.
# 1                              MNS Pro Companies, Inc.
# 2                        New Yorkers International LLC
# 3                                Surge Streams Limited
# 4                                         Hi Color Inc
# ..                                                 ...
# 530  TRATADO DE LIBRE COMERCIO LIMITED LIABILITY CO...
# 531                       FOUR J'S TRANSPORTATION INC.
# 532                     AFFORDABLE OFFICE SERVICES INC
# 533           Watts Architecture & Engineering, D.P.C.
# 534                              MARACLE BUILDERS, LLC
#
#     Trade Name ("Doing Business As ...")  DUNS Number  Parent DUNS Number  \
# 0                                    NaN    117990138                 NaN
# 1                                    NaN     78514224                 NaN
# 2                                    NaN     78791446                 NaN
# 3                                    NaN    114059203                 NaN
# 4                                    NaN    117737154                 NaN
# ..                                   ...          ...                 ...
# 530                                  NaN     57733622                 NaN
# 531                                  NaN     54809704                 NaN
# 532                                  NaN     73776580                 NaN
# 533     Watts Architecture & Engineering    131686693         131686693.0
# 534                                  NaN    117074053                 NaN
#
#              Address, line 1  Address, line 2      City State         Zip  \
# 0               28 BRYANT RD              NaN     other    NY  10512-5617
# 1    807 South Geddes Street              NaN     other    NY  13204-3617
# 2        8508 Astoria Blvd 1              NaN     other    NY  11369-1656
# 3            248 Winthrop St              NaN  brooklyn    NY  11225-3812
# 4    14598 Guy R Brewer Blvd              NaN    queens    NY  11434-5284
# ..                       ...              ...       ...   ...         ...
# 530       3136 44TH ST APT 2              NaN    queens    NY  11103-2397
# 531       132 PEARL ST STE A              NaN     other    NY  10573-7615
# 532      728 E 136TH ST FL 3              NaN     bronx    NY  10454-3431
# 533      95 Perry St Ste 300              NaN     other    NY  14203-3030
# 534         2882 EDGEMERE DR              NaN     other    NY  14612-1153
#
#                  Phone Number    Fax Number                 E-mail Address  \
# 0                833-964-1011           NaN       oyane@trainedforcare.com
# 1                315-657-1846           NaN        moe@mnsprocompanies.com
# 2                347-566-1011           NaN         impartialnyc@gmail.com
# 3                347-233-7022           NaN      737arobinson787@gmail.com
# 4    833-444-6257 x0                    NaN           hicolorinc@gmail.com
# ..                        ...           ...                            ...
# 530              917-514-7556           NaN            amy@marrsmakers.com
# 531              914-708-5997  203-748-3725        billing@fourjsmedia.com
# 532              718-292-5010  718-292-4995               sales@aosnyc.com
# 533              716-206-5137  716-206-5199         jhenschel@watts-ae.com
# 534              585-230-0987           NaN  maraclebldrs@rochester.rr.com
#
#                     WWW Page                E-Commerce Website  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN          http://surgestreams.com/
# 4            www.HiColor.com                               NaN
# ..                       ...                               ...
# 530                      NaN                               NaN
# 531      fourjstransport.com  https://www.fourjstransport.com/
# 532                      NaN                               NaN
# 533  HTTP://WWW.WATTS-AE.COM             https://watts-ae.com/
# 534                      NaN                               NaN
#
#           Contact Person  County Code (3 digit)  Congressional District  \
# 0         Oyane  Jacques                     79                      18
# 1         Moses Scoggins                     67                      24
# 2            Nimer Dewan                     81                      14
# 3          Asim Robinson                     47                       9
# 4              Sigh West                     81                       5
# ..                   ...                    ...                     ...
# 530           Amy Sheets                     81                      14
# 531      Polly T Herring                    119                      17
# 532   alexander m pernas                      5                      15
# 533  Jessica  K Henschel                     29                      26
# 534      Leonard Maracle                     55                      25
#
#      Metropolitan Statistical Area CAGE Code  Year Established  \
# 0                           5600.0     8ZGC9              2020
# 1                           8160.0     6UK94              2012
# 2                           5600.0     8PJP7              2011
# 3                           5600.0     8SER7              2018
# 4                           5600.0     8TFY2              2019
# ..                             ...       ...               ...
# 530                         5600.0     8MSU9              2013
# 531                         5600.0     8PH69              1998
# 532                         5600.0     57SU2              2001
# 533                         1280.0     1FHY2              2012
# 534                         6840.0     8BTF9              2008
#
#     Accepts Government Credit Card? GSA Advantage Contract(s)
# 0                   [  ] Yes [X] No                       NaN
# 1                   [X] Yes [  ] No                       NaN
# 2                   [X] Yes [  ] No                       NaN
# 3                   [X] Yes [  ] No                       NaN
# 4                   [X] Yes [  ] No                       NaN
# ..                              ...                       ...
# 530                 [X] Yes [  ] No                       NaN
# 531                 [X] Yes [  ] No                       NaN
# 532                 [  ] Yes [X] No                       NaN
# 533                 [X] Yes [  ] No                       NaN
# 534                 [  ] Yes [X] No                       NaN
#
# [535 rows x 25 columns]

# %%
newdf = df[df.City.isin(["bronx", "brooklyn","queens","manhattan","staten island", "other"])]

# %%
len(newdf)
# Out:
# 535

# %%
data = newdf.groupby("City")['City'].count()

# %%
# data.plot.pie(autopct="%.1f%%")

# %%
pie, ax = plt.subplots(figsize=[10,6])
labels = data.keys()
plt.pie(x=data, autopct="%.1f%%", labels=labels, pctdistance=0.5)
plt.title(" Percentage of Businesses W/ SBA loans by City", fontsize=14);
# pie.savefig("SBAPieChart.png")
plt.show()

# %% [markdown]
# # Conclusion <a id='3'></a>:
#     from this pie chart you can see a majority of the SBA loans went to cities in New York that are outside of the 5 boroughs. Therefore from this data I would say more resources should be allocated to small businesses within boroughs such as The Bronx which has only 5 percent
